# %%
import numpy as np
import pandas as pd

# %%
#libraries for plotting
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set_style('darkgrid')

# %%
# loading iris flower dataset

df = sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.sample(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 128           6.4          2.8           5.6          2.1   virginica
# 42            4.4          3.2           1.3          0.2      setosa
# 78            6.0          2.9           4.5          1.5  versicolor
# 126           6.2          2.8           4.8          1.8   virginica
# 61            5.9          3.0           4.2          1.5  versicolor

# %%
df.shape
# Out:
# (150, 5)

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df.nunique() # find out the unique elements in our dataframe
# Out:
# sepal_length    35
# sepal_width     23
# petal_length    43
# petal_width     22
# species          3
# dtype: int64

# %%
# Statistics of features data
df.describe(include='all')
# Out:
#         sepal_length  sepal_width  petal_length  petal_width    species
# count     150.000000   150.000000    150.000000   150.000000        150
# unique           NaN          NaN           NaN          NaN          3
# top              NaN          NaN           NaN          NaN  virginica
# freq             NaN          NaN           NaN          NaN         50
# mean        5.843333     3.057333      3.758000     1.199333        NaN
# std         0.828066     0.435866      1.765298     0.762238        NaN
# min         4.300000     2.000000      1.000000     0.100000        NaN
# 25%         5.100000     2.800000      1.600000     0.300000        NaN
# 50%         5.800000     3.000000      4.350000     1.300000        NaN
# 75%         6.400000     3.300000      5.100000     1.800000        NaN
# max         7.900000     4.400000      6.900000     2.500000        NaN

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
# Show duplicate rows
df[df.duplicated()]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 142           5.8          2.7           5.1          1.9  virginica

# %%
df['species'].value_counts()
# Out:
# virginica     50
# setosa        50
# versicolor    50
# Name: species, dtype: int64

# %%
# Checking missing values
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
# countplot for target species
sns.countplot(x='species', data=df)
plt.title('Count of Species')
# Out:
# Text(0.5, 1.0, 'Count of Species')

# %%
# visualisation of relations

# %%
sns.relplot(x='sepal_length', y='species', data=df, hue='species')

# %%
sns.relplot(x='sepal_width', y='species', data=df, hue='species')

# %%
sns.relplot(x='petal_length', y='species', data=df, hue='species')

# %%
sns.relplot(x='petal_width', y='species', data=df, hue='species')

# %%
# values of features
fig, axes = plt.subplots(2, 2, figsize=(10, 10))

sns.boxplot(x='species', y='sepal_length', data=df, ax=axes[0][0])
sns.boxplot(x='species', y='sepal_width', data=df, ax=axes[0][1])
sns.boxplot(x='species', y='petal_length', data=df, ax=axes[1][0])
sns.boxplot(x='species', y='petal_width', data=df, ax=axes[1][1])

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# distribution of values
fig, axes = plt.subplots(2, 2, figsize=(10, 10))

sns.distplot(x=df['sepal_length'], ax=axes[0][0])
sns.distplot(x=df['sepal_length'], ax=axes[0][1])
sns.distplot(x=df['petal_length'], ax=axes[1][0])
sns.distplot(x=df['petal_width'], ax=axes[1][1])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Relation between sepal features
plt.figure(figsize=(10, 8))
sns.scatterplot(x='sepal_length', y='sepal_width', data=df, hue='species')

# %%
# Relation between petal features
plt.figure(figsize=(10, 8))
sns.scatterplot(x='petal_length', y='petal_width', data=df, hue='species')

# %%
# Pairplot
sns.pairplot(df, hue='species')

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
numerical_columns_df = df.iloc[:, 0:4]
numerical_columns_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
sns.heatmap(numerical_columns_df.corr(), cmap='Blues', annot=True)

# %%
# Input
X = numerical_columns_df
print(X)
X = X.values
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
# Output
y = df['species']

# %%
#train_test_split
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
x_train.shape, x_test.shape
# Out:
# ((112, 4), (38, 4))

# %%
y_train.shape, y_test.shape
# Out:
# ((112,), (38,))

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

#fitting the model
model.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression()

# %%
# solve warning
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(max_iter=1000)

#fitting the model
model.fit(x_train,y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_preds = model.predict(x_test)
y_preds
# Out:
# array(['virginica', 'versicolor', 'setosa', 'virginica', 'setosa',
#        'virginica', 'setosa', 'versicolor', 'versicolor', 'versicolor',
#        'virginica', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'setosa', 'versicolor', 'versicolor', 'setosa',
#        'setosa', 'virginica', 'versicolor', 'setosa', 'setosa',
#        'virginica', 'setosa', 'setosa', 'versicolor', 'versicolor',
#        'setosa', 'virginica', 'versicolor', 'setosa', 'virginica',
#        'virginica', 'versicolor', 'setosa', 'virginica'], dtype=object)

# %%
# Accuracy
from sklearn.metrics import accuracy_score
accuracy_score(y_preds, y_test)*100
# Out:
# 97.36842105263158

# %%
model.predict(numerical_columns_df[0:3])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:439: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   f"X has feature names, but {self.__class__.__name__} was fitted without"
# array(['setosa', 'setosa', 'setosa'], dtype=object)

# %%
import joblib
joblib.dump(model, 'IRIS_Classifier')
# Out:
# ['IRIS_Classifier']
